# %%
import pathlib

# %%
import geopandas
data = geopandas.read_file('L4132R.shp/m_L4132R_p.shp')

# %%
data.head()
# Out:
#   TEKSTI  RYHMA  LUOKKA  TASTAR  KORTAR  KORARV  KULKUTAPA    KOHDEOSO  \
# 0   None     64   32421    5000       0     0.0          0  1812247077
# 1   None     64   32421    5000       0     0.0          0  1718796908
# 2   None     64   32421    5000       0     0.0          0  2081894330
# 3   None     64   32421   20000       0     0.0          0   411167695
# 4   None     64   32421   20000       0     0.0          0   411173698
#
#    AINLAHDE SYNTYHETKI  ... TOLEFT  FROMRIGHT  TORIGHT  TIENIM2  TIENIM3  \
# 0         1   20210819  ...      0          0        0     None     None
# 1         1   20210819  ...      0          0        0     None     None
# 2         1   20211015  ...      0          0        0     None     None
# 3         1   20210819  ...      0          0        0     None     None
# 4         1   20210819  ...      0          0        0     None     None
#
#    TIENIM4  TIENIM5  KUNTA_NRO  KUNTA  \
# 0     None     None          0   None
# ...

# %%
data.columns
# Out:
# Index(['TEKSTI', 'RYHMA', 'LUOKKA', 'TASTAR', 'KORTAR', 'KORARV', 'KULKUTAPA',
#        'KOHDEOSO', 'AINLAHDE', 'SYNTYHETKI', 'KUOLHETKI', 'KARTOGLK',
#        'ALUEJAKOON', 'VERSUH', 'SUUNTA', 'SIIRT_DX', 'SIIRT_DY', 'KORKEUS',
#        'PYSYVAID', 'ATTR3', 'TIENUM', 'OSANUM', 'TIEOSA', 'PAALLY', 'YKSSUU',
#        'VAPKOR', 'VALMAS', 'PITUUS', 'FROMLEFT', 'TOLEFT', 'FROMRIGHT',
#        'TORIGHT', 'TIENIM2', 'TIENIM3', 'TIENIM4', 'TIENIM5', 'KUNTA_NRO',
#        'KUNTA', 'geometry'],
#       dtype='object')

# %%
data = data[["RHYMA", "LUOKKA", "geometry"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data = data[["LUOKKA", "RHYMA", "geometry"]]
#
# File ~/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# ...
